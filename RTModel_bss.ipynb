# %%
# %matplotlib inline
import numpy as np 
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import arviz as az
import pymc3 as pm
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
rtdata = pd.read_csv("./data/rt_tidy.csv")
rtdata.head(10)
# Out:
#    Unnamed: 0     X.1 language  user_id        trait stim_id  order    rt  \
# 0           1  606711      SPA     9654    confident  BM-040     41  1903
# 1           2  331376       HU     5381  responsible  WF-015     33   799
# 2           3  162777      ENG     2734   attractive  LF-208     14  1226
# 3           4  614094      SPA     9753       caring  BF-008     67  4561
# 4           5  732055       PT    11726   aggressive  BF-201     36   912
# 5           6  353796      ENG     5692   attractive  BF-047    105  1446
# 6           7  437062      ENG     6884         mean  WM-256     73  1991
# 7           8   88967      ENG     1541          old  BF-004      3  1437
# 8           9  438455      ENG     6897       caring  LM-243     63  2546
# 9          10  701944      ENG    11134   aggressive  LM-219     13  1629
#
#    rating country  ...        ethnicity.x      lab block    X  Race  Gender  \
# 0       3      CO  ...                NaN  COL_004     2   51     B       M
# 1       7      HU  ...  magyar, kaukázusi  HUN_001     2   93     W       F
# 2       1      US  ...           Hispanic  USA_038     2   63     L       F
# 3       7      CO  ...            ninguno  COL_004     1   35     B       F
# 4       3      PT  ...         Caucasiana  POR_001     2   40     B       F
# 5       1      AU  ...          Caucasian  AUS_007     1   39     B       F
# 6       1      CA  ...        South Asian  CAN_018     1  120     W       M
# 7       4      US  ...              White  USA_113     2   32     B       F
# 8       6      CA  ...              white  CAN_018     2   86     L       M
# 9       2      US  ...              white  USA_054     1   81     L       M
#
#          Age ethnicity.y  gender    log_rt
# 0  26.952381       black    male  7.551187
# 1  24.211111       white  female  6.683361
# 2  24.642857      latinx  female  7.111512
# 3  24.574713       black  female  8.425297
# 4  27.400000       black  female  6.815640
# 5  34.213483       black  female  7.276556
# 6  30.961538       white    male  7.596392
# 7  26.983696       black  female  7.270313
# 8  21.642857      latinx    male  7.842279
# 9  26.703704      latinx    male  7.395722
#
# [10 rows x 22 columns]

# %% [markdown]
# # Visualization

# %%
# show unique values for a certain column
print(f"Column 'col2' has unique values:")
print(rtdata['trait'].unique())
print(rtdata['rating'].unique())
# Out:
# Column 'col2' has unique values:
# ['confident' 'responsible' 'attractive' 'caring' 'aggressive' 'mean' 'old'
#  'emostable' 'sociable' 'unhappy' 'dominant' 'trustworthy' 'weird'
#  'intelligent']
# [3 7 1 4 6 2 5 8 9]

# %%
datatest = rtdata
# Use the astype() method to convert the numerical data to a factor using the 'category' data type
datatest['rating'] = datatest['rating'].astype('category')

# %%
# Define a list of participants to include in the filter
include = ['unhappy']
include2= ['BM-040']

# Use the `isin()` method to create a boolean mask and use boolean indexing to filter the DataFrame
grouptrait = datatest[datatest['trait'].isin(include)]
grouptrait2 = datatest[datatest['stim_id'].isin(include2)]

# %%
import seaborn as sns

sns.boxplot(data=data, x='rating', y='rt', hue='Race')
#plt.legend().remove()  # Remove the legend
plt.show()

# %% [markdown]
# Some conclusions
# 1. extreme ratings, quicker speed
# 2. factors: face sex, face race, face features (determined by ratings) = reaction time
#
# face features = average of all positive ratings - average of all negative ratings

# %%
rtdata.groupby(['stim_id']).rt.plot.density()
# Out:
# stim_id
# AF-203    AxesSubplot(0.125,0.11;0.775x0.77)
# AF-204    AxesSubplot(0.125,0.11;0.775x0.77)
# AF-205    AxesSubplot(0.125,0.11;0.775x0.77)
# AF-209    AxesSubplot(0.125,0.11;0.775x0.77)
# AF-211    AxesSubplot(0.125,0.11;0.775x0.77)
#                          ...
# WM-237    AxesSubplot(0.125,0.11;0.775x0.77)
# WM-242    AxesSubplot(0.125,0.11;0.775x0.77)
# WM-243    AxesSubplot(0.125,0.11;0.775x0.77)
# WM-244    AxesSubplot(0.125,0.11;0.775x0.77)
# WM-256    AxesSubplot(0.125,0.11;0.775x0.77)
# Name: rt, Length: 120, dtype: object

# %% [markdown]
# # test hypothesis

# %% [markdown]
# # hypothesis 3
#
# more extreme ratings, quicker speed

# %%
import pandas as pd
from scipy.stats import spearmanr

df3 = data

# add new columns to df3 

df3['rating_new'] = df3['rating'].replace({6: 4, 7: 3, 8: 2, 9: 1})
df3.head(10)
# Out:
#    Unnamed: 0     X.1 language  user_id        trait stim_id  order    rt  \
# 0           1  606711      SPA     9654    confident  BM-040     41  1903
# 1           2  331376       HU     5381  responsible  WF-015     33   799
# 2           3  162777      ENG     2734   attractive  LF-208     14  1226
# 3           4  614094      SPA     9753       caring  BF-008     67  4561
# 4           5  732055       PT    11726   aggressive  BF-201     36   912
# 5           6  353796      ENG     5692   attractive  BF-047    105  1446
# 6           7  437062      ENG     6884         mean  WM-256     73  1991
# 7           8   88967      ENG     1541          old  BF-004      3  1437
# 8           9  438455      ENG     6897       caring  LM-243     63  2546
# 9          10  701944      ENG    11134   aggressive  LM-219     13  1629
#
#   rating country  ...      lab  block    X Race  Gender        Age  \
# 0      3      CO  ...  COL_004      2   51    B       M  26.952381
# 1      7      HU  ...  HUN_001      2   93    W       F  24.211111
# 2      1      US  ...  USA_038      2   63    L       F  24.642857
# 3      7      CO  ...  COL_004      1   35    B       F  24.574713
# 4      3      PT  ...  POR_001      2   40    B       F  27.400000
# 5      1      AU  ...  AUS_007      1   39    B       F  34.213483
# 6      1      CA  ...  CAN_018      1  120    W       M  30.961538
# 7      4      US  ...  USA_113      2   32    B       F  26.983696
# 8      6      CA  ...  CAN_018      2   86    L       M  21.642857
# 9      2      US  ...  USA_054      1   81    L       M  26.703704
#
#   ethnicity.y  gender    log_rt rating_new
# 0       black    male  7.551187          3
# 1       white  female  6.683361          3
# 2      latinx  female  7.111512          1
# 3       black  female  8.425297          3
# 4       black  female  6.815640          3
# 5       black  female  7.276556          1
# 6       white    male  7.596392          1
# 7       black  female  7.270313          4
# 8      latinx    male  7.842279          4
# 9      latinx    male  7.395722          2
#
# [10 rows x 23 columns]

# %%
import pandas as pd
from scipy.stats import f_oneway
#ra = ['1', '5']

#df3test = df3.loc[df['rating_new'].isin(ra)]

#rating_new = pd.factorize(df3.rating_new)

bins = [0, 1.5, 4.5, 6]

# convert the 'numbers' column to categorical variables using pd.cut()
df3['rating_nn'] = pd.cut(df3['rating_new'], bins=bins, labels=['high', 'medium', 'low'])

# Perform ANOVA
fstat, pval = f_oneway(df3.loc[df3['rating_nn'] == 'high', 'log_rt'], 
                        df3.loc[df3['rating_nn'] == 'medium', 'log_rt'], 
                        df3.loc[df3['rating_nn'] == 'low', 'log_rt'])

# Print results
print('ANOVA F-statistic:', fstat)
print('p-value:', pval)

df3.head(10)
# Out:
# ANOVA F-statistic: 655.3673247912199
# p-value: 2.0325742672834114e-283
#    Unnamed: 0     X.1 language  user_id        trait stim_id  order    rt  \
# 0           1  606711      SPA     9654    confident  BM-040     41  1903
# 1           2  331376       HU     5381  responsible  WF-015     33   799
# 2           3  162777      ENG     2734   attractive  LF-208     14  1226
# 3           4  614094      SPA     9753       caring  BF-008     67  4561
# 4           5  732055       PT    11726   aggressive  BF-201     36   912
# 5           6  353796      ENG     5692   attractive  BF-047    105  1446
# 6           7  437062      ENG     6884         mean  WM-256     73  1991
# 7           8   88967      ENG     1541          old  BF-004      3  1437
# 8           9  438455      ENG     6897       caring  LM-243     63  2546
# 9          10  701944      ENG    11134   aggressive  LM-219     13  1629
#
#   rating country  ... block    X Race Gender        Age  ethnicity.y  gender  \
# 0      3      CO  ...     2   51    B      M  26.952381        black    male
# 1      7      HU  ...     2   93    W      F  24.211111        white  female
# 2      1      US  ...     2   63    L      F  24.642857       latinx  female
# 3      7      CO  ...     1   35    B      F  24.574713        black  female
# 4      3      PT  ...     2   40    B      F  27.400000        black  female
# 5      1      AU  ...     1   39    B      F  34.213483        black  female
# 6      1      CA  ...     1  120    W      M  30.961538        white    male
# 7      4      US  ...     2   32    B      F  26.983696        black  female
# 8      6      CA  ...     2   86    L      M  21.642857       latinx    male
# 9      2      US  ...     1   81    L      M  26.703704       latinx    male
#
#      log_rt  rating_new rating_nn
# 0  7.551187           3    medium
# 1  6.683361           3    medium
# 2  7.111512           1      high
# 3  8.425297           3    medium
# 4  6.815640           3    medium
# 5  7.276556           1      high
# 6  7.596392           1      high
# 7  7.270313           4    medium
# 8  7.842279           4    medium
# 9  7.395722           2    medium
#
# [10 rows x 24 columns]

# %%
fig, ax = plt.subplots()
df3.boxplot(column='rt', by='rating_nn', ax=ax)
ax.set_xlabel('Rating')
ax.set_ylabel('RT')
plt.show()

# %%
sns.boxplot(x='rating_nn', y='rt', hue='Race', data=df3)
# Out:
# <AxesSubplot:xlabel='rating_nn', ylabel='rt'>

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('rating_nn')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\675688584.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('rating_nn')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#
#    3798                                 stats['cihi'] = ci[1]
#
#    3799
#
# -> 3800         artists = self.bxp(bxpstats, positions=positions, widths=widths,
#
#    3801                            vert=vert, patch_artist=patch_artist,
#
#    3802                            shownotches=notch, showmeans=showmeans,
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder)
#
#    3970             positions = list(range(1, N + 1))
#
#    3971         elif len(positions) != N:
#
# -> 3972             raise ValueError(datashape_message.format("positions"))
#
#    3973
#
#    3974         positions = np.array(positions)
#
#
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('rating_nn')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\675688584.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('rating_nn')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#
#    3798                                 stats['cihi'] = ci[1]
#
#    3799
#
# -> 3800         artists = self.bxp(bxpstats, positions=positions, widths=widths,
#
#    3801                            vert=vert, patch_artist=patch_artist,
#
#    3802                            shownotches=notch, showmeans=showmeans,
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder)
#
#    3970             positions = list(range(1, N + 1))
#
#    3971         elif len(positions) != N:
#
# -> 3972             raise ValueError(datashape_message.format("positions"))
#
#    3973
#
#    3974         positions = np.array(positions)
#
#
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('rating_nn')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\675688584.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('rating_nn')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#
#    3798                                 stats['cihi'] = ci[1]
#
#    3799
#
# -> 3800         artists = self.bxp(bxpstats, positions=positions, widths=widths,
#
#    3801                            vert=vert, patch_artist=patch_artist,
#
#    3802                            shownotches=notch, showmeans=showmeans,
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder)
#
#    3970             positions = list(range(1, N + 1))
#
#    3971         elif len(positions) != N:
#
# -> 3972             raise ValueError(datashape_message.format("positions"))
#
#    3973
#
#    3974         positions = np.array(positions)
#
#
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('rating_nn')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\675688584.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], positions = df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('rating_nn')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#
#    3798                                 stats['cihi'] = ci[1]
#
#    3799
#
# -> 3800         artists = self.bxp(bxpstats, positions=positions, widths=widths,
#
#    3801                            vert=vert, patch_artist=patch_artist,
#
#    3802                            shownotches=notch, showmeans=showmeans,
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder)
#
#    3970             positions = list(range(1, N + 1))
#
#    3971         elif len(positions) != N:
#
# -> 3972             raise ValueError(datashape_message.format("positions"))
#
#    3973
#
#    3974         positions = np.array(positions)
#
#
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

for ax, race in zip(axes.flatten(), df3['Race'].unique()):
    df_race = df3[df3['Race'] == race]
    ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
    ax.set_title(f'Race: {race}')
    ax.set_xlabel('Rating')
    ax.set_ylabel('rt')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_20980\450963352.py in <module>
#
#       3 for ax, race in zip(axes.flatten(), df3['Race'].unique()):
#
#       4     df_race = df3[df3['Race'] == race]
#
# ----> 5     ax.boxplot(df_race['rt'], by=df_race['rating_nn'])
#
#       6     ax.set_title(f'Race: {race}')
#
#       7     ax.set_xlabel('Rating')
#
#
#
# d:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#
#    1410     def inner(ax, *args, data=None, **kwargs):
#
#    1411         if data is None:
#
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#
#    1413
#
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
#
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
import seaborn as sns

sns.boxplot(data=data, x='rating', y='rt', hue='Race')
#plt.legend().remove()  # Remove the legend
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=data, x='rating', y='rt', hue='Race')
#plt.legend().remove()  # Remove the legend
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=data, x='rating', y='rt', hue='Race')
#plt.legend().remove()  # Remove the legend
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=data, x='rating', y='rt', hue='Race')
#plt.legend().remove()  # Remove the legend
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=data, x='rating', y='rt', hue='Race')
#plt.legend().remove()  # Remove the legend
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=data, x='rating', y='rt', hue='Race')
#plt.legend().remove()  # Remove the legend
plt.show()

# %%
import pandas as pd
from scipy.stats import ttest_ind

# Subset the data for groups A and B
df_ab = df3.loc[df3['rating_nn'].isin(['medium', 'low'])]

# Perform t-test
tstat, pval = ttest_ind(df_ab.loc[df_ab['rating_nn'] == 'medium', 'log_rt'], 
                        df_ab.loc[df_ab['rating_nn'] == 'low', 'log_rt'])

# Print results
print('t-test statistic:', tstat)
print('p-value:', pval)
# Out:
# t-test statistic: 2.9654824956982764
# p-value: 0.003022909196870932

# %%
# spearman 
corr, pval = spearmanr(df3['rating_new'], df3['rt'])
print('Spearman correlation coefficient:', corr)
print('p-value:', pval)

# %%
import seaborn as sns
#grid = sns.FacetGrid(data, col='Race', col_wrap=3)
#grid.map(sns.histplot, 'rt')
sns.boxplot(x='rating_nn', y='log_rt', data=df3)
# Out:
# <AxesSubplot:xlabel='rating_nn', ylabel='log_rt'>

# %% [markdown]
# ## hypothesis 2
#
# face sex, face race

# %%
df2 = data

include = ['unhappy']

trait = df2[df2['trait'].isin(include)]

# %%
sns.boxplot(x='Gender', y='rt', data=trait)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='rt'>

# %% [markdown]
# ## hypothesis 1
#
# a complete list of variables:
# 'confident' 'responsible' 'attractive' 'caring' 'emostable' 'sociable' 'trustworthy'  'intelligent'
# 'dominant'

# %%
df = data

df['rating'] = pd.to_numeric(df['rating'])


neg = ['unhappy']
pos = ['sociable', 'caring']

# Calculate the average positive score and average negative score for each stimulus
pos_mean = df[df['trait'].isin(pos)].groupby('stim_id')['rating'].mean()
neg_mean = df[df['trait'].isin(neg)].groupby('stim_id')['rating'].mean()

# Subtract the average negative score from the average positive score for each stimulus to get the actual score
actual_score = pos_mean - neg_mean

# Merge the actual score back into the original DataFrame
df = pd.merge(df, actual_score, on='stim_id', suffixes=('','_mean'))
df['actual_score'] = df['rating_mean'] - df['rating']

# Drop the extra columns used for calculating actual score
#df.drop(['rating_mean'], axis=1, inplace=True)

# Print the updated DataFrame
df.head(10)
# Out:
#    Unnamed: 0     X.1 language  user_id        trait stim_id  order    rt  \
# 0           1  606711      SPA     9654    confident  BM-040     41  1903
# 1         209  285313      ENG     4685        weird  BM-040     67  2695
# 2         383  172951      ENG     2905        weird  BM-040     28  1470
# 3         411  115010      GER     1893     dominant  BM-040     80  3015
# 4         644  760354      ENG    12183      unhappy  BM-040    109  2572
# 5        1109  487189      ENG     7727       caring  BM-040     52  2501
# 6        1217  207833      ENG     3392    confident  BM-040     58  1740
# 7        1816  190760      ENG     3160  trustworthy  BM-040     83  1888
# 8        1921  159147       NL     2657      unhappy  BM-040     75  1600
# 9        2105  163429      ENG     2744       caring  BM-040     37  1589
#
#    rating country  ... block   X Race Gender        Age  ethnicity.y gender  \
# 0       3      CO  ...     2  51    B      M  26.952381        black   male
# 1       6      US  ...     1  51    B      M  26.952381        black   male
# 2       5      CA  ...     1  51    B      M  26.952381        black   male
# 3       8      AT  ...     1  51    B      M  26.952381        black   male
# 4       4      US  ...     2  51    B      M  26.952381        black   male
# 5       4      CA  ...     1  51    B      M  26.952381        black   male
# 6       4      US  ...     2  51    B      M  26.952381        black   male
# 7       9      US  ...     2  51    B      M  26.952381        black   male
# 8       2      NL  ...     2  51    B      M  26.952381        black   male
# 9       5      US  ...     2  51    B      M  26.952381        black   male
#
#      log_rt  rating_mean actual_score
# 0  7.551187     1.084456    -1.915544
# 1  7.899153     1.084456    -4.915544
# 2  7.293018     1.084456    -3.915544
# 3  8.011355     1.084456    -6.915544
# 4  7.852439     1.084456    -2.915544
# 5  7.824446     1.084456    -2.915544
# 6  7.461640     1.084456    -2.915544
# 7  7.543273     1.084456    -7.915544
# 8  7.377759     1.084456    -0.915544
# 9  7.370860     1.084456    -3.915544
#
# [10 rows x 24 columns]

# %%
df['rating_mean'] = (df['rating_mean'] + 3)*1000

# Get summary statistics for each column
summary = df.rating_mean.describe()

# Print the summary statistics
print(summary)

print(df['rating_mean'].unique())
# Out:
# count    95756.000000
# mean      6431.343884
# std       1168.820204
# min       3237.460815
# 25%       5588.766789
# 50%       6435.483871
# 75%       7172.580645
# max       9354.768322
# Name: rating_mean, dtype: float64
# [7084.45642408 7175.6440281  5283.86809269 6963.59397418 7749.07658212
#  6408.69327501 6112.90322581 4803.125      5448.61859838 9354.76832242
#  7298.61813279 9345.97309998 7177.71883289 7073.18789585 6966.86159844
#  7270.0729927  6582.51231527 6007.84313725 5989.47368421 6403.62981851
#  6435.48387097 6467.23163842 5934.7826087  6855.69852941 6676.41544807
#  5281.76229508 5084.30769231 5798.0952381  7831.2390415  6532.04172876
#  7137.39669421 6589.4909688  7040.6504065  6713.51351351 4801.04923325
#  8612.44836918 7538.46153846 5903.91993328 5567.42963192 6478.67746289
#  4699.12312751 5322.37288136 7397.9020979  6487.44731537 7172.58064516
#  6035.60250391 4761.11111111 6091.95402299 6249.43181818 4242.85293251
#  7157.22142516 6014.03286979 5737.88084372 5798.37398374 6113.8238573
#  5753.74939526 3237.46081505 6192.11111111 5025.64102564 6677.5210084
#  7223.89420885 4471.43552311 4791.29824561 4886.36363636 7008.4375
#  4336.40677966 7649.66063348 8809.80392157 6829.67032967 6035.54803216
#  6675.52447552 7295.42966612 5725.96496226 5588.76678877 8894.87179487
#  9078.56290996 7526.11487073 8351.85185185 8056.36710067 4769.4235589
#  5500.51652893 4408.72210953 6842.73504274 5382.68759902 5684.57594531
#  5889.98250219 6171.2962963  8194.44444444 8978.6862334  4286.82170543
#  6203.38983051 5501.61290323 6721.13821138 5242.38089999 7468.8057041
#  6168.6351706  7030.81232493 5511.64874552 5736.31840796 6640.88114754
#  5381.96480938 6922.34169654 7618.70155039 7114.37908497 6361.24031008
#  5852.08711434 7144.36363636 6458.33333333 7951.10161871 7618.25396825
#  5632.57575758 5344.82758621 5394.99659632 5559.30232558 7432.35294118
#  7361.46632566 8053.39435545 5529.90695614 7114.56814131 6446.10034774]

# %%
# define the bins
bins = [0, 4000, 5000, 6000, 7000, 8000, 9000, 10000]

# convert the 'numbers' column to categorical variables using pd.cut()
df['favalence'] = pd.cut(df['rating_mean'], bins=bins, labels=['1', '2', '3', '4','5','6','7'])

df_filtered = df.loc[df['rt'] < 4000]


sns.boxplot(x='favalence', y='rt', data=df_filtered)
# Out:
# <AxesSubplot:xlabel='favalence', ylabel='rt'>

# %% [markdown]
# # Hierarchical bayeisan model

# %%
lang_idxs, lang = pd.factorize(data.lang)

coords = {
    "lang":
     lang,
    "obs_id": np.arange(len(lang_idxs)),
}

# %%
from sklearn.preprocessing import LabelEncoder
#import pandas as pd
label_encoder = LabelEncoder()
data['smre'] = label_encoder.fit_transform(data['Sm'])

#Label encoding is a technique that assigns a unique numerical value to each category in a categorical variable. 
#This technique is useful when there is an inherent ordering to the categories. 
#You can use the sklearn library to perform label encoding using the LabelEncoder() function.

# %%
#Sm = pd.factorize(data.Sm)

# %%
with pm.Model(coords=coords) as model_ExGaussian3:
    m_alpha = pm.Normal("m_alpha", mu=0, sigma=10)  
    sig_alpha = pm.HalfNormal("sig_alpha", 10)
    m_beta = pm.Normal("m_beta", mu=0, sigma=10)  
    sig_beta = pm.HalfNormal("sig_beta", 10)
   
    # prior 
    alpha = pm.Normal('alpha', mu=m_alpha,sd=sig_alpha, dims="lang")
    beta = pm.Normal('beta',mu=m_beta,sd=sig_beta, dims="lang")
    
    # x
    x = pm.Data("x", data.smre, dims="obs_id")
    lang_idx = pm.Data("lang_idx", lang_idxs, dims="obs_id")
    mu = pm.Deterministic("mu",  alpha[lang_idxs]+ beta[lang_idxs]*x) 
    nu = pm.HalfNormal('nu', 100)
    sigma = pm.HalfNormal('sigma', 100)

    y_obs = pm.ExGaussian("y_obs", mu=mu,sigma=sigma,nu=nu, observed=data.rt, dims="obs_id")

# %%
#conda install -c conda-forge python-graphviz
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::holoviews==1.15.0=py39hecd8cb5_0
#   - defaults/osx-64::imageio==2.19.3=py39hecd8cb5_0
#   - defaults/noarch::requests-file==1.5.1=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-image==0.19.2=py39hae1ba45_0
#   - defaults/osx-64::anaconda-project==0.11.1=py39hecd8cb5_0
#   - defaults/osx-64::conda==23.3.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyterlab==3.4.4=py39hecd8cb5_0
#   - defaults/osx-64::datashader==0.14.1=py39hecd8cb5_0
#   - defaults/osx-64::scrapy==2.6.2=py39hecd8cb5_0
#   - defaults/osx-64::matplotlib==3.5.2=py39hecd8cb5_0
#   - defaults/osx-64::hvplot==0.8.0=py39hecd8cb5_0
#   - defaults/osx-64::plotly==5.9.0=py39hecd8cb5_0
#   - defaults/osx-64::conda-build==3.22.0=py39hecd8cb5_0
#   - defaults/osx-64::sphinx==5.0.2=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.3.2=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_1
#   - defaults/osx-64::matplotlib-base==3.5.2=py39hfb0c5b7_0
#   - defaults/osx-64::dask==2022.7.0=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-client==1.11.0=py39hecd8cb5_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/osx-64::numpydoc==1.4.0=py39hecd8cb5_0
#   - defaults/noarch::intake==0.6.5=pyhd3eb1b0_0
#   - defaults/osx-64::navigator-updater==0.3.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_8
#   - defaults/osx-64::bokeh==2.4.3=py39hecd8cb5_0
#   - defaults/osx-64::colorcet==3.0.0=py39hecd8cb5_0
#   - defaults/osx-64::conda-repo-cli==1.0.20=py39hecd8cb5_0
#   - defaults/osx-64::pyct==0.4.8=py39hecd8cb5_1
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda==custom=py39_1
#   - defaults/osx-64::_anaconda_depends==2022.10=py39_2
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-64::spyder==5.3.3=py39hecd8cb5_0
#   - defaults/osx-64::panel==0.13.1=py39hecd8cb5_0
#   - defaults/noarch::tldextract==3.2.0=pyhd3eb1b0_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/nanwang/opt/anaconda3
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libxcb-1.13                |    h0d85af4_1004         305 KB  conda-forge
#     pillow-9.2.0               |   py39h579eac4_0        44.7 MB  conda-forge
#     pthread-stubs-0.4          |    hc929b4f_1001           6 KB  conda-forge
#     requests-2.28.2            |     pyhd8ed1ab_1          56 KB  conda-forge
#     tenacity-8.2.2             |     pyhd8ed1ab_0          22 KB  conda-forge
#     xorg-libxau-1.0.9          |       h35c211d_0          11 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h35c211d_0          17 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        45.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   libxcb             conda-forge/osx-64::libxcb-1.13-h0d85af4_1004
#   pillow             conda-forge/osx-64::pillow-9.2.0-py39h579eac4_0
#   pthread-stubs      conda-forge/osx-64::pthread-stubs-0.4-hc929b4f_1001
#   requests           conda-forge/noarch::requests-2.28.2-pyhd8ed1ab_1
#   tenacity           conda-forge/noarch::tenacity-8.2.2-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-64::xorg-libxau-1.0.9-h35c211d_0
#   xorg-libxdmcp      conda-forge/osx-64::xorg-libxdmcp-1.1.3-h35c211d_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-h033912b_0
#   certifi            pkgs/main/osx-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1t-hca72f7f_0 --> conda-forge::openssl-1.1.1t-hfd90126_0
#
#
#
# Downloading and Extracting Packages
# pthread-stubs-0.4    | 6 KB      |                                       |   0%
# xorg-libxdmcp-1.1.3  | 17 KB     |                                       |   0%
#
# libxcb-1.13          | 305 KB    |                                       |   0%
#
#
# requests-2.28.2      | 56 KB     |                                       |   0%
#
#
#
# pillow-9.2.0         | 44.7 MB   |                                       |   0%
#
#
#
#
# tenacity-8.2.2       | 22 KB     |                                       |   0%
#
#
#
#
#
# pthread-stubs-0.4    | 6 KB      | ##################################### | 100%
#
#
#
# pillow-9.2.0         | 44.7 MB   |                                       |   0%
#
#
#
# pillow-9.2.0         | 44.7 MB   |                                       |   0%
#
# libxcb-1.13          | 305 KB    | #9                                    |   5%
#
#
#
# pillow-9.2.0         | 44.7 MB   |                                       |   0%
#
#
#
# pillow-9.2.0         | 44.7 MB   |                                       |   0%
#
#
#
#
# tenacity-8.2.2       | 22 KB     | ###########################           |  73%
#
# libxcb-1.13          | 305 KB    | #####8                                |  16%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 1                                     |   0%
#
#
#
#
# tenacity-8.2.2       | 22 KB     | ##################################### | 100%
#
#
#
#
# tenacity-8.2.2       | 22 KB     | ##################################### | 100%
#
# libxcb-1.13          | 305 KB    | ###########6                          |  31%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 1                                     |   0%
#
# libxcb-1.13          | 305 KB    | ###############5                      |  42%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 2                                     |   1%
#
# libxcb-1.13          | 305 KB    | #########################2            |  68%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 2                                     |   1%
#
#
#
#
#
# xorg-libxau-1.0.9    | 11 KB     | ##################################### | 100%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 3                                     |   1%
#
# libxcb-1.13          | 305 KB    | ##################################### | 100%
#
# libxcb-1.13          | 305 KB    | ##################################### | 100%
#
#
#
#
#
# xorg-libxau-1.0.9    | 11 KB     | ##################################### | 100%
#
#
# requests-2.28.2      | 56 KB     | ##########6                           |  29%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 6                                     |   2%
# xorg-libxdmcp-1.1.3  | 17 KB     | ###################################1  |  95%
# xorg-libxdmcp-1.1.3  | 17 KB     | ##################################### | 100%
#
#
# requests-2.28.2      | 56 KB     | #####################2                |  58%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 8                                     |   2%
#
#
#
# pillow-9.2.0         | 44.7 MB   | 9                                     |   3%
#
#
# requests-2.28.2      | 56 KB     | ##################################### | 100%
#
#
# requests-2.28.2      | 56 KB     | ##################################### | 100%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #                                     |   3%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #2                                    |   3%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #2                                    |   3%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #3                                    |   4%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #4                                    |   4%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #5                                    |   4%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #6                                    |   4%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #6                                    |   5%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #7                                    |   5%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #7                                    |   5%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #8                                    |   5%
#
#
#
# pillow-9.2.0         | 44.7 MB   | #9                                    |   5%
#
#
#
# pillow-9.2.0         | 44.7 MB   | ##                                    |   5%
#
#
#
# pillow-9.2.0         | 44.7 MB   | ##                                    |   6%
#
#
#
# pillow-9.2.0         | 44.7 MB   | ##1                                   |   6%
#
#
#
# pillow-9.2.0         | 44.7 MB   | ##2                                   |   6%
#
#
#
# pillow-9.2.0         | 44.7 MB   | ##3                                   |   6%
#
#
#
# pillow-9.2.0         | 44.7 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://conda.anaconda.org/conda-forge/osx-64/pillow-9.2.0-py39h579eac4_0.tar.bz2>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pm.model_to_graphviz(model_ExGaussian3)

# %%
# 检查先验
with model_ExGaussian3:
    prior_checks = pm.sample_prior_predictive(samples=1000)

# %%
az.plot_density(
    {'mu':prior_checks['mu']}
    )
plt.show()

# %%
az.plot_density(
    {
        'alpha': prior_checks['alpha']
    }
    )
plt.show()
# Out:
# /Users/nanwang/opt/anaconda3/lib/python3.9/site-packages/arviz/data/base.py:220: UserWarning: More chains (1000) than draws (2). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(

# %%
az.plot_density(
    {
        'beta': prior_checks['beta']
    }
    )
plt.show()

# %%
az.plot_density(
    {'sigma': prior_checks['sigma']
    }
    )
plt.show()

# %%
az.plot_density(
    {'nu': prior_checks['nu']
    }
    )
plt.show()

# %%
x = np.random.randint(2, size = 12) #生成50个假数据，取值为[0,1]

for a, b in zip(prior_checks["alpha"], prior_checks["beta"]):
    y1 = a + b * x 
    plt.plot(x, y1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/33/549r3s6x3rg3lg7h3bjcgf6r0000gn/T/ipykernel_3186/74574434.py in <module>
#       2
#       3 for a, b in zip(prior_checks["alpha"], prior_checks["beta"]):
# ----> 4     y1 = a + b * x
#       5     plt.plot(x, y1)
#
# ValueError: operands could not be broadcast together with shapes (2,) (12,)

# %%
#xcode-select --install
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/33/549r3s6x3rg3lg7h3bjcgf6r0000gn/T/ipykernel_66134/3991006731.py in <module>
# ----> 1 xcode-select --install
#
# NameError: name 'xcode' is not defined

# %%
#MCMC sampling
with model_ExGaussian3:
    trace_ExGaussian3 = pm.sample(draws = 1000, tune= 500, target_accept=0.8, chains=2, cores= 2,return_inferencedata=True,init="adapt_diag")
# Out:
# WARNING (theano.tensor.opt): Optimization Warning: The Op erfcx does not provide a C implementation. As well as being potentially slow, this also disables loop fusion.
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, nu, beta, alpha, sig_beta, m_beta, sig_alpha, m_alpha]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:36&lt;00:00 Sampling 2 chains, 145 divergences]
#     </div>
# /Users/nanwang/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:624: RuntimeWarning: overflow encountered in _beta_ppf
#   return _boost._beta_ppf(q, a, b)
# /Users/nanwang/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:624: RuntimeWarning: overflow encountered in _beta_ppf
#   return _boost._beta_ppf(q, a, b)
# Sampling 2 chains for 500 tune and 1_000 draw iterations (1_000 + 2_000 draws total) took 49 seconds.
# There were 39 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9301263835709297, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 106 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 25% for some parameters.

# %%
az.plot_trace(trace_ExGaussian3, var_names=['alpha','beta'])#分开呈现
plt.show()

# %%
az.plot_trace(trace_ExGaussian3, var_names=['alpha','beta'], combined=True)
# Out:
# array([[<AxesSubplot:title={'center':'alpha'}>,
#         <AxesSubplot:title={'center':'alpha'}>],
#        [<AxesSubplot:title={'center':'beta'}>,
#         <AxesSubplot:title={'center':'beta'}>]], dtype=object)

# %%
# Obtain posterior distribution for the effect of semantic relatedness
semantic_effect = trace_ExGaussian3['beta']

# Calculate mean and credible interval for the effect of semantic relatedness
#semantic_mean = np.mean(semantic_effect)
#semantic_ci = pm.stats.hpd(semantic_effect, credible_interval=0.95)
#print("Mean of the effect of semantic relatedness:", semantic_mean)
#print("95% credible interval of the effect of semantic relatedness:", semantic_ci)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/33/549r3s6x3rg3lg7h3bjcgf6r0000gn/T/ipykernel_3186/1255484653.py in <module>
#       1 # Obtain posterior distribution for the effect of semantic relatedness
# ----> 2 semantic_effect = trace_ExGaussian3['beta']
#       3
#       4 # Calculate mean and credible interval for the effect of semantic relatedness
#       5 #semantic_mean = np.mean(semantic_effect)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/arviz/data/inference_data.py in __getitem__(self, key)
#     251         """Get item by key."""
#     252         if key not in self._groups_all:
# --> 253             raise KeyError(key)
#     254         return getattr(self, key)
#     255
#
# KeyError: 'beta'

# %%
az.summary(trace_ExGaussian3, var_names=['alpha','beta'])
# Out:
#                mean      sd   hdi_3%   hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha[yes]  895.218  10.091  875.519   912.978      0.349    0.247     834.0
# alpha[no]   992.009  10.768  971.523  1011.858      0.355    0.251     917.0
# beta[yes]   -15.164  10.231  -34.971     3.271      0.355    0.255     833.0
# beta[no]    -16.998  11.565  -39.944     2.828      0.457    0.323     662.0
#
#             ess_tail  r_hat
# alpha[yes]    1037.0    1.0
# alpha[no]      918.0    1.0
# beta[yes]      991.0    1.0
# beta[no]      1123.0    1.0

# %%
with model_ExGaussian3:
    #计算后验预测分布
    ppc_y = pm.sample_posterior_predictive(trace_ExGaussian3.posterior) 
#将ppc_y转化为InferenceData对象合并到trace中
az.concat(trace_ExGaussian3, az.from_pymc3(posterior_predictive=ppc_y), inplace=True)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:01&lt;00:00]
#     </div>
# Got error No model on context stack. trying to find log_likelihood in translation.
# /Users/nanwang/opt/anaconda3/lib/python3.9/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
az.plot_ppc(trace_ExGaussian3)
plt.show()

# %%
az.plot_forest(trace_ExGaussian3, var_names=['alpha', 'beta'], combined=True);
