# %% [markdown]
# 代码还是有些问题，我遇到了MCMC采样不成功的问题，感觉一是数据量大，二是相比于之前的广义线性模型，这个7点评分的自变量复杂了很多，我没来得及试如果按照你之前吧rating分成三个部分的方法。
# 然后在过程中我为了简化模型把超先验也删去了，也调整了先验里的参数，但是还是不收敛
# 所以接下来要做的是
# 你可以继续试试现在这个能不能跑的通
# 把rating分成两个或者三个并进行哑变量处理，然后还是做广义的分层模型
# 做一个不用贝叶斯的，单纯是分层线性模型，rt还是满足exgaussian分布（这个我之前在R里面做了一部分了）

# %%
# import packages
import numpy as np 
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import arviz as az
import pymc3 as pm
#设置seed
np.random.seed(123)

# %%
data = pd.read_csv("./data/rt_tidy.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0     X.1 language  user_id        trait stim_id  order    rt  \
# 0           1  606711      SPA     9654    confident  BM-040     41  1903
# 1           2  331376       HU     5381  responsible  WF-015     33   799
# 2           3  162777      ENG     2734   attractive  LF-208     14  1226
# 3           4  614094      SPA     9753       caring  BF-008     67  4561
# 4           5  732055       PT    11726   aggressive  BF-201     36   912
# 5           6  353796      ENG     5692   attractive  BF-047    105  1446
# 6           7  437062      ENG     6884         mean  WM-256     73  1991
# 7           8   88967      ENG     1541          old  BF-004      3  1437
# 8           9  438455      ENG     6897       caring  LM-243     63  2546
# 9          10  701944      ENG    11134   aggressive  LM-219     13  1629
#
#    rating country  ...        ethnicity.x      lab block    X  Race  Gender  \
# 0       3      CO  ...                NaN  COL_004     2   51     B       M
# 1       7      HU  ...  magyar, kaukázusi  HUN_001     2   93     W       F
# 2       1      US  ...           Hispanic  USA_038     2   63     L       F
# 3       7      CO  ...            ninguno  COL_004     1   35     B       F
# 4       3      PT  ...         Caucasiana  POR_001     2   40     B       F
# 5       1      AU  ...          Caucasian  AUS_007     1   39     B       F
# 6       1      CA  ...        South Asian  CAN_018     1  120     W       M
# 7       4      US  ...              White  USA_113     2   32     B       F
# 8       6      CA  ...              white  CAN_018     2   86     L       M
# 9       2      US  ...              white  USA_054     1   81     L       M
#
#          Age ethnicity.y  gender    log_rt
# 0  26.952381       black    male  7.551187
# 1  24.211111       white  female  6.683361
# 2  24.642857      latinx  female  7.111512
# 3  24.574713       black  female  8.425297
# 4  27.400000       black  female  6.815640
# 5  34.213483       black  female  7.276556
# 6  30.961538       white    male  7.596392
# 7  26.983696       black  female  7.270313
# 8  21.642857      latinx    male  7.842279
# 9  26.703704      latinx    male  7.395722
#
# [10 rows x 22 columns]

# %% [markdown]
# # Preprocess

# %%
# create the new column that uses centralized rating
data['ratingcen'] = (data['rating'] - 5).abs() + 1

# %%
pip install sns
# Out:
# Collecting sns
#   Downloading sns-0.1.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sns
#   Building wheel for sns (setup.py) ... done
#   Created wheel for sns: filename=sns-0.1-py3-none-any.whl size=2639 sha256=e642a601a052ca726340a92f81e3e860e2f5446556ca8670040337d4d4d83b24
#   Stored in directory: /Users/nanwang/Library/Caches/pip/wheels/ff/12/fa/4d724fdfed493cfe12b239ae9a0bc26b2fd85bb7dc9ecde7c3
# Successfully built sns
# Installing collected packages: sns
# Successfully installed sns-0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
#   File "/var/folders/33/549r3s6x3rg3lg7h3bjcgf6r0000gn/T/ipykernel_45030/4176958353.py", line 3
#     module 'sns' has no attribute 'FacetGrid'
#            ^
# SyntaxError: invalid syntax

# %%
import sns
# Create a FacetGrid with boxplots
g = sns.FacetGrid(data, col='trait', col_wrap=2, sharex=False, sharey=False, height=4, aspect=1.5)
g.map(sns.boxplot, 'ratingcen', 'log_rt')

# Add labels and title
g.set_axis_labels('ratingcen', 'Reaction Time')
g.fig.suptitle('Boxplot of Reaction Time by rating, Across Different Stimulus Conditions')
plt.subplots_adjust(top=0.9)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/33/549r3s6x3rg3lg7h3bjcgf6r0000gn/T/ipykernel_45030/4211364578.py in <module>
#       1 import sns
#       2 # Create a FacetGrid with boxplots
# ----> 3 g = sns.FacetGrid(data, col='trait', col_wrap=2, sharex=False, sharey=False, height=4, aspect=1.5)
#       4 g.map(sns.boxplot, 'ratingcen', 'log_rt')
#       5
#
# AttributeError: module 'sns' has no attribute 'FacetGrid'

# %%
# Create a FacetGrid with boxplots
g = sns.FacetGrid(data, col='stim_id', col_wrap=2, sharex=False, sharey=False, height=4, aspect=1.5)
g.map(sns.boxplot, 'ratingcen', 'log_rt')

# Add labels and title
g.set_axis_labels('ratingcen', 'Reaction Time')
g.fig.suptitle('Boxplot of Reaction Time by rating, Across Different Stimulus Conditions')
plt.subplots_adjust(top=0.9)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/33/549r3s6x3rg3lg7h3bjcgf6r0000gn/T/ipykernel_45030/3812081605.py in <module>
#       1 # Create a FacetGrid with boxplots
# ----> 2 g = sns.FacetGrid(data, col='stim_id', col_wrap=2, sharex=False, sharey=False, height=4, aspect=1.5)
#       3 g.map(sns.boxplot, 'ratingcen', 'log_rt')
#       4
#       5 # Add labels and title
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Model 1

# %%
with pm.Model() as model_ExGaussian3:
    m_alpha = pm.Normal("m_alpha", mu=0, sigma=100)  
    m_beta = pm.Normal("m_beta", mu=0, sigma=50) 
    sig_alpha = pm.HalfNormal("sig_alpha", 100) 
    sig_beta = pm.HalfNormal("sig_beta", 100)
   
    # prior
    alpha = pm.Normal('alpha', mu=m_alpha,sd=sig_alpha)
    beta = pm.Normal('beta',mu=m_beta,sd=sig_beta)
    nu = pm.HalfNormal('nu', 100)
    sigma = pm.HalfNormal('sigma', 200)

# %%
with model_ExGaussian3:
    prior_checks = pm.sample_prior_predictive(samples=50)

# %%
pm.model_to_graphviz(model_ExGaussian3)

# %%
z = np.random.randint(1, 8,  100) #生成50个假数据，取值为[0,1]

for a, b in zip(prior_checks["alpha"], prior_checks["beta"]):
    y = a + b * z 
    plt.plot(z, y)

# %%
with pm.Model() as model_ExGaussian3:
    m_alpha = pm.Normal("m_alpha", mu=0, sigma=100)  
    m_beta = pm.Normal("m_beta", mu=0, sigma=50) 
    sig_alpha = pm.HalfNormal("sig_alpha", 50) 
    sig_beta = pm.HalfNormal("sig_beta", 50)
   
    # prior
    alpha = pm.Normal('alpha', mu=m_alpha,sd=sig_alpha)
    beta = pm.Normal('beta',mu=m_beta,sd=sig_beta)
    nu = pm.HalfNormal('nu', 50)
    sigma = pm.HalfNormal('sigma', 100)

    # x
    x = pm.Data("x", data.ratingcen)
    mu = pm.Deterministic("mu",  alpha+ beta*x) 

    y_obs = pm.ExGaussian("y_obs", mu=mu,sigma=sigma,nu=nu, observed=data.rt)

# %%
with model_ExGaussian3:
    trace = pm.sample(draws=1000,tune=800,target_accept=0.9,
                      chains=2, cores=2, init="adapt_diag")
# Out:
# WARNING (theano.tensor.opt): Optimization Warning: The Op erfcx does not provide a C implementation. As well as being potentially slow, this also disables loop fusion.
# /Users/nanwang/opt/anaconda3/lib/python3.9/site-packages/deprecat/classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, nu, beta, alpha, sig_beta, sig_alpha, m_beta, m_alpha]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='572' class='' max='3600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.89% [572/3600 06:19&lt;33:27 Sampling 2 chains, 0 divergences]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, callback, discard_tuned_samples, mp_ctx, pickle_backend, **kwargs)
#    1495             with sampler:
# -> 1496                 for draw in sampler:
#    1497                     trace = traces[draw.chain - chain]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymc3/parallel_sampling.py in __iter__(self)
#     478         while self._active:
# --> 479             draw = ProcessAdapter.recv_draw(self._active)
#     480             proc, is_last, draw, tuning, stats, warns = draw
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymc3/parallel_sampling.py in recv_draw(processes, timeout)
#     345         pipes = [proc._msg_pipe for proc in processes]
# --> 346         ready = multiprocessing.connection.wait(pipes)
#     347         if not ready:
#
# ~/opt/anaconda3/lib/python3.9/multiprocessing/connection.py in wait(object_list, timeout)
#     935             while True:
# --> 936                 ready = selector.select(timeout)
#     937                 if ready:
#
# ~/opt/anaconda3/lib/python3.9/selectors.py in select(self, timeout)
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/33/549r3s6x3rg3lg7h3bjcgf6r0000gn/T/ipykernel_4733/2114459961.py in <module>
#       1 with model_ExGaussian3:
# ----> 2     trace = pm.sample(draws=1000,tune=800,target_accept=0.9,
#       3                       chains=2, cores=2, init="adapt_diag")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/deprecat/classic.py in wrapper_function(wrapped_, instance_, args_, kwargs_)
#     213                         else:
#     214                             warnings.warn(message, category=category, stacklevel=_routine_stacklevel)
# --> 215                 return wrapped_(*args_, **kwargs_)
#     216
#     217             return wrapper_function(wrapped)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, initvals, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, start, return_inferencedata, idata_kwargs, mp_ctx, pickle_backend, **kwargs)
#     573         _print_step_hierarchy(step)
#     574         try:
# --> 575             trace = _mp_sample(**sample_args, **parallel_args)
#     576         except pickle.PickleError:
#     577             _log.warning("Could not pickle model, sampling singlethreaded.")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, callback, discard_tuned_samples, mp_ctx, pickle_backend, **kwargs)
#    1520     except KeyboardInterrupt:
#    1521         if discard_tuned_samples:
# -> 1522             traces, length = _choose_chains(traces, tune)
#    1523         else:
#    1524             traces, length = _choose_chains(traces, 0)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymc3/sampling.py in _choose_chains(traces, tune)
#    1546     lengths = [max(0, len(trace) - tune) for trace in traces]
#    1547     if not sum(lengths):
# -> 1548         raise ValueError("Not enough samples to build a trace.")
#    1549
#    1550     idxs = np.argsort(lengths)
#
# ValueError: Not enough samples to build a trace.

# %%
az.plot_trace(trace,var_names=['alpha','beta','sigma'])

# %%
with model_ExGaussian3:
    ppc_y = pm.sample_posterior_predictive(trace.posterior) 
az.concat(trace, az.from_pymc3(posterior_predictive=ppc_y), inplace=True)
az.plot_ppc(trace)

# %% [markdown]
# # Model 2
#
# Model description:
#
# 1. 根据preprocessing那边的可视化结果，当ratingcen=2， 5时，rt差别最大，因此本次建模只筛选rating=2，5
# 2. x=ratingcen, y=rt, 以country, stimulus, trait为分层变量，一个个往上加，本次只加一个 country（代表文化）的分层变量

# %%
# Filter rows based on rating
data2 = data[(data['ratingcen'] == 2) | (data['ratingcen'] == 5)]

data2['country'].unique()
# Out:
# array(['US', 'AU', 'CA', 'DE', 'AE', 'RU', 'NO', 'MY', 'NL', 'NZ', 'MX',
#        'SK', 'CO', 'BR', 'BE', 'KE', 'RS', 'HK', 'GB', 'CN', 'ZA', 'CL',
#        'IN', 'TR', 'SE', 'SV', 'EC', 'GR', 'HU', 'FR', 'TW', 'CH', 'DK',
#        'AT', 'RO', 'ES', 'NG', 'PT', 'HT', 'TH', 'IR', 'CC', 'PE', 'AR',
#        'PL', 'IT', 'TN', 'UG', 'EG', 'UA', 'GH', nan, 'FI', 'BY', 'LU',
#        'CY', 'BG', 'ID', 'KH', 'MO', 'BD', 'KR', 'VN', 'CI', 'IE', 'AF',
#        '--', 'AD', 'IL', 'KZ', 'LK', 'AX', 'UY', 'RW'], dtype=object)

# %%
country_idxs, country = pd.factorize(data2.country)

coords = {
    "country":
     country,
    "obs_id": np.arange(len(country_idxs)),
}

# %%
with pm.Model(coords=coords) as model_ExGaussian2:
    m_alpha = pm.Normal("m_alpha", mu=0, sigma=10)  
    sig_alpha = pm.HalfNormal("sig_alpha", 10)
    m_beta = pm.Normal("m_beta", mu=0, sigma=10)  
    sig_beta = pm.HalfNormal("sig_beta", 10)
   
    # prior 
    alpha = pm.Normal('alpha', mu=m_alpha,sd=sig_alpha, dims="country")
    beta = pm.Normal('beta',mu=m_beta,sd=sig_beta, dims="country")
    
    # x
    x = pm.Data("x", data2.ratingcen, dims="obs_id") # x is either two or five
    country_idx = pm.Data("country_idx", country_idxs, dims="obs_id")
    mu = pm.Deterministic("mu",  alpha[country_idxs]+ beta[country_idxs]*x) 
    nu = pm.HalfNormal('nu', 100)
    sigma = pm.HalfNormal('sigma', 100)
    
    
    y_obs = pm.ExGaussian("y_obs", mu=mu,sigma=sigma,nu=nu, observed=data2.rt, dims="obs_id")

# %%
pm.model_to_graphviz(model_ExGaussian2)

# %%
# 检查先验
with model_ExGaussian3:
    prior_checks = pm.sample_prior_predictive(samples=1000)

# %%
az.plot_density(
    {'mu':prior_checks['mu']}
    )
plt.show()

# %%
az.plot_density(
    {
        'alpha': prior_checks['alpha']
    }
    )
plt.show()

# %%
az.plot_density(
    {
        'beta': prior_checks['beta']
    }
    )
plt.show()

# %%
az.plot_density(
    {'sigma': prior_checks['sigma']
    }
    )
plt.show()

# %%
az.plot_density(
    {'nu': prior_checks['nu']
    }
    )
plt.show()

# %%
x = np.random.randint(2, size = 12) 

for a, b in zip(prior_checks["alpha"], prior_checks["beta"]):
    y1 = a + b * x 
    plt.plot(x, y1)

# %%
#MCMC sampling
with model_ExGaussian2:
    trace_ExGaussian3 = pm.sample(draws = 1000, tune= 500, target_accept=0.8, chains=2, cores= 2,return_inferencedata=True,init="adapt_diag")
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, nu, beta, alpha, sig_beta, m_beta, sig_alpha, m_alpha]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 29:57&lt;00:00 Sampling 2 chains, 1,000 divergences]
#     </div>
# /Users/nanwang/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py:624: RuntimeWarning: overflow encountered in _beta_ppf
#   return _boost._beta_ppf(q, a, b)
# Sampling 2 chains for 500 tune and 1_000 draw iterations (1_000 + 2_000 draws total) took 1811 seconds.
# The acceptance probability does not match the target. It is 0.9746456674858823, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain contains only diverging samples. The model is probably misspecified.
# The acceptance probability does not match the target. It is 0.5492272033733141, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
az.plot_trace(trace_ExGaussian3, var_names=['alpha','beta'])
plt.show()

# %%
# Generate summary table
summary_table = az.summary(trace_ExGaussian3, var_names=['alpha', 'beta'])

# Display the full table
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(summary_table)
    

#special countries: AE, HK, IN, TN, UG, EG, VN, IE, AF, AD, IL, KZ, LK, AX, UY
# Out:
#                mean       sd   hdi_3%   hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha[US]   813.941  235.983  577.765  1070.977    166.002  140.355       3.0
# alpha[AU]   845.910  268.441  578.010  1150.632    188.570  159.335       3.0
# alpha[CA]   820.607  243.471  577.871  1102.273    170.834  144.275       3.0
# alpha[DE]   952.509  376.116  577.816  1393.034    263.844  222.802       3.0
# alpha[AE]   540.833   86.506  345.829   686.896     27.435   19.999      15.0
# alpha[RU]  1005.140  429.602  577.918  1516.840    301.013  254.055       3.0
# alpha[NO]   908.704  332.094  577.958  1295.764    232.918  196.668       3.0
# alpha[MY]   879.215  303.015  577.854  1241.474    212.217  179.073       3.0
# alpha[NL]   770.194  196.638  577.926  1034.408    135.857  113.958       3.0
# alpha[NZ]   871.811  296.550  578.001  1235.091    207.178  174.630       3.0
# beta[KR]     84.727   72.409  -45.772   146.341     44.314   39.709       3.0
# beta[VN]     39.933   55.799  -84.462    85.275     30.148   23.453       4.0
# beta[CI]     46.569   46.807  -64.448   105.748     19.431   14.496       6.0
# beta[IE]     25.955   41.764  -77.832    76.217     14.261   10.449      10.0
# beta[AF]     38.801   62.580  -86.641    89.761     36.402   28.819       3.0
# beta[--]     62.346   60.356  -68.785   111.240     32.131   24.918       4.0
# beta[AD]      2.966   37.461  -80.610    78.562      0.527    8.713     215.0
# beta[IL]     38.022   44.660  -59.476    90.440     21.421   16.299       5.0
# beta[KZ]     93.243   75.134  -39.433   156.626     45.715   40.111       3.0
# beta[LK]     85.232   94.761  -67.674   171.613     61.778   54.356       3.0
# beta[AX]     46.929   73.661  -87.457   108.823     44.824   35.935       3.0
# beta[UY]     59.401   69.896  -66.122   118.037     42.501   36.052       3.0
# beta[RW]     52.495   65.220  -56.195   110.781     41.855   36.458       3.0
#
#            ess_tail  r_hat
# alpha[US]      37.0   2.03
# alpha[AU]      29.0   1.88
# alpha[CA]      78.0   1.85
# alpha[DE]      51.0   1.87
# alpha[AE]      88.0   1.82
# alpha[RU]      68.0   1.89
# alpha[NO]      55.0   1.88
# alpha[MY]      48.0   1.94
# alpha[NL]      46.0   1.83
# alpha[NZ]      58.0   1.86
# alpha[MX]      80.0   1.83
# alpha[SK]      40.0   1.83
# alpha[CO]      33.0   1.83
# alpha[BR]      73.0   1.83
# alpha[BE]      26.0   1.84
# alpha[KE]      57.0   1.87
# alpha[RS]      80.0   1.84
# alpha[HK]      73.0   1.87
# alpha[GB]      56.0   1.83
# alpha[CN]      77.0   1.86
# alpha[ZA]      31.0   1.87
# alpha[CL]      89.0   1.89
# alpha[IN]      77.0   1.84
# alpha[TR]      22.0   1.89
# alpha[SE]      56.0   1.84
# alpha[SV]      96.0   1.88
# alpha[EC]      34.0   1.90
# alpha[GR]      97.0   1.83
# alpha[HU]      69.0   1.83
# alpha[FR]      30.0   1.92
# alpha[TW]     102.0   1.82
# alpha[CH]      38.0   2.00
# alpha[DK]      52.0   1.86
# alpha[AT]      75.0   1.86
# alpha[RO]      41.0   1.98
# alpha[ES]      46.0   1.84
# alpha[NG]      41.0   1.89
# alpha[PT]      54.0   1.83
# alpha[HT]      72.0   1.82
# alpha[TH]      21.0   1.88
# alpha[IR]      51.0   1.84
# alpha[CC]      79.0   1.82
# alpha[PE]      61.0   1.84
# alpha[AR]      47.0   1.84
# alpha[PL]      37.0   1.85
# alpha[IT]      68.0   1.83
# alpha[TN]      53.0   1.85
# alpha[UG]      58.0   1.83
# alpha[EG]      83.0   1.87
# alpha[UA]      81.0   1.85
# alpha[GH]      58.0   1.83
# alpha[FI]      58.0   1.93
# alpha[BY]      57.0   1.83
# alpha[LU]     108.0   1.83
# alpha[CY]      66.0   1.83
# alpha[BG]      84.0   1.83
# alpha[ID]      64.0   1.84
# alpha[KH]      68.0   1.85
# alpha[MO]      57.0   1.86
# alpha[BD]      52.0   1.84
# alpha[KR]      73.0   1.87
# alpha[VN]      80.0   1.92
# alpha[CI]      71.0   1.83
# alpha[IE]      68.0   1.84
# alpha[AF]      72.0   1.85
# alpha[--]      59.0   1.88
# alpha[AD]      66.0   1.83
# alpha[IL]      75.0   1.81
# alpha[KZ]      72.0   1.83
# alpha[LK]      88.0   1.88
# alpha[AX]      76.0   1.89
# alpha[UY]      56.0   1.83
# alpha[RW]      89.0   1.83
# beta[US]       23.0   1.84
# beta[AU]       12.0   1.88
# beta[CA]       17.0   2.20
# beta[DE]       11.0   1.95
# beta[AE]       98.0   1.83
# beta[RU]       22.0   1.86
# beta[NO]       19.0   1.86
# beta[MY]       23.0   1.84
# beta[NL]       12.0   2.17
# beta[NZ]       18.0   2.02
# beta[MX]       40.0   2.18
# beta[SK]       11.0   2.01
# beta[CO]       29.0   2.06
# beta[BR]       55.0   1.83
# beta[BE]       27.0   2.14
# beta[KE]       38.0   2.13
# beta[RS]       13.0   2.19
# beta[HK]       76.0   1.82
# beta[GB]       12.0   2.12
# beta[CN]       12.0   2.17
# beta[ZA]       15.0   2.18
# beta[CL]       15.0   1.86
# beta[IN]       47.0   1.83
# beta[TR]       11.0   2.00
# beta[SE]       59.0   1.83
# beta[SV]       15.0   2.17
# beta[EC]       16.0   1.99
# beta[GR]       49.0   1.94
# beta[HU]       23.0   1.92
# beta[FR]       16.0   2.17
# beta[TW]      130.0   1.89
# beta[CH]       20.0   1.88
# beta[DK]       11.0   2.13
# beta[AT]       37.0   1.85
# beta[RO]       12.0   2.18
# beta[ES]       11.0   2.21
# beta[NG]       66.0   1.92
# beta[PT]       12.0   2.20
# beta[HT]       56.0   1.87
# beta[TH]       81.0   2.03
# beta[IR]       11.0   2.23
# beta[CC]       65.0   1.97
# beta[PE]       12.0   2.12
# beta[AR]       66.0   1.98
# beta[PL]       24.0   1.86
# beta[IT]       21.0   2.14
# beta[TN]       61.0   1.81
# beta[UG]       69.0   1.94
# beta[EG]       97.0   1.85
# beta[UA]       24.0   1.98
# beta[GH]       54.0   2.17
# beta[FI]       19.0   2.20
# beta[BY]       65.0   2.20
# beta[LU]       69.0   1.89
# beta[CY]       66.0   2.15
# beta[BG]       30.0   2.23
# beta[ID]       21.0   1.92
# beta[KH]       81.0   2.16
# beta[MO]       16.0   2.21
# beta[BD]       45.0   2.12
# beta[KR]       18.0   1.85
# beta[VN]       65.0   2.22
# beta[CI]       60.0   2.15
# beta[IE]       53.0   2.19
# beta[AF]       49.0   2.13
# beta[--]       93.0   1.85
# beta[AD]       54.0   1.81
# beta[IL]       52.0   1.95
# beta[KZ]       21.0   2.11
# beta[LK]       12.0   2.21
# beta[AX]       40.0   2.23
# beta[UY]       47.0   1.87
# beta[RW]       12.0   2.14

# %%
with model_ExGaussian2:
    #计算后验预测分布
    ppc_y = pm.sample_posterior_predictive(trace_ExGaussian3.posterior) 
#将ppc_y转化为InferenceData对象合并到trace中
az.concat(trace_ExGaussian3, az.from_pymc3(posterior_predictive=ppc_y), inplace=True)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:06&lt;00:00]
#     </div>
# Got error No model on context stack. trying to find log_likelihood in translation.
# /Users/nanwang/opt/anaconda3/lib/python3.9/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
az.plot_forest(trace_ExGaussian3, var_names=['alpha', 'beta'], combined=True);

# %% [markdown]
# # Model 3
#
# 这时候再加layer
